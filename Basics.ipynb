# %%
import pandas as pd
import matplotlib.pyplot  as plt
# %matplotlib inline

# %%
recent_grads = pd.read_csv('recent-grads.csv')
recent_grads.head()
# Out:
#    Rank  Major_code                                      Major    Total  \
# 0     1        2419                      PETROLEUM ENGINEERING   2339.0
# 1     2        2416             MINING AND MINERAL ENGINEERING    756.0
# 2     3        2415                  METALLURGICAL ENGINEERING    856.0
# 3     4        2417  NAVAL ARCHITECTURE AND MARINE ENGINEERING   1258.0
# 4     5        2405                       CHEMICAL ENGINEERING  32260.0
#
#        Men    Women Major_category  ShareWomen  Sample_size  Employed  \
# 0   2057.0    282.0    Engineering    0.120564           36      1976
# 1    679.0     77.0    Engineering    0.101852            7       640
# 2    725.0    131.0    Engineering    0.153037            3       648
# 3   1123.0    135.0    Engineering    0.107313           16       758
# 4  21239.0  11021.0    Engineering    0.341631          289     25694
#
#        ...        Part_time  Full_time_year_round  Unemployed  \
# ...

# %%
recent_grads.columns
# Out:
# Index(['Rank', 'Major_code', 'Major', 'Total', 'Men', 'Women',
#        'Major_category', 'ShareWomen', 'Sample_size', 'Employed', 'Full_time',
#        'Part_time', 'Full_time_year_round', 'Unemployed', 'Unemployment_rate',
#        'Median', 'P25th', 'P75th', 'College_jobs', 'Non_college_jobs',
#        'Low_wage_jobs'],
#       dtype='object')

# %%
recent_grads.tail()
# Out:
#      Rank  Major_code                   Major   Total     Men   Women  \
# 168   169        3609                 ZOOLOGY  8409.0  3050.0  5359.0
# 169   170        5201  EDUCATIONAL PSYCHOLOGY  2854.0   522.0  2332.0
# 170   171        5202     CLINICAL PSYCHOLOGY  2838.0   568.0  2270.0
# 171   172        5203   COUNSELING PSYCHOLOGY  4626.0   931.0  3695.0
# 172   173        3501         LIBRARY SCIENCE  1098.0   134.0   964.0
#
#                Major_category  ShareWomen  Sample_size  Employed  \
# 168    Biology & Life Science    0.637293           47      6259
# 169  Psychology & Social Work    0.817099            7      2125
# 170  Psychology & Social Work    0.799859           13      2101
# 171  Psychology & Social Work    0.798746           21      3777
# 172                 Education    0.877960            2       742
#
#          ...        Part_time  Full_time_year_round  Unemployed  \
# 168      ...             2190                  3602         304
# ...

# %%
recent_grads.iloc[0]
# Out:
# Rank                                        1
# Major_code                               2419
# Major                   PETROLEUM ENGINEERING
# Total                                    2339
# Men                                      2057
# Women                                     282
# Major_category                    Engineering
# ShareWomen                           0.120564
# Sample_size                                36
# Employed                                 1976
# Full_time                                1849
# Part_time                                 270
# Full_time_year_round                     1207
# Unemployed                                 37
# Unemployment_rate                   0.0183805
# Median                                 110000
# P25th                                   95000
# P75th                                  125000
# College_jobs                             1534
# Non_college_jobs                          364
# ...

# %%
recent_grads.describe()
# Out:
#              Rank   Major_code          Total            Men          Women  \
# count  173.000000   173.000000     172.000000     172.000000     172.000000
# mean    87.000000  3879.815029   39370.081395   16723.406977   22646.674419
# std     50.084928  1687.753140   63483.491009   28122.433474   41057.330740
# min      1.000000  1100.000000     124.000000     119.000000       0.000000
# 25%     44.000000  2403.000000    4549.750000    2177.500000    1778.250000
# 50%     87.000000  3608.000000   15104.000000    5434.000000    8386.500000
# 75%    130.000000  5503.000000   38909.750000   14631.000000   22553.750000
# max    173.000000  6403.000000  393735.000000  173809.000000  307087.000000
#
#        ShareWomen  Sample_size       Employed      Full_time      Part_time  \
# count  172.000000   173.000000     173.000000     173.000000     173.000000
# mean     0.522223   356.080925   31192.763006   26029.306358    8832.398844
# ...

# %%
row_data_count = len(recent_grads)
row_data_count
# Out:
# 173

# %%
recent_grads = recent_grads.dropna()
cleaned_data_count = len(recent_grads)
cleaned_data_count
# Out:
# 172

# %%
recent_grads.plot(x='Sample_size', y='Median', kind='scatter', title='Median v Sample Size')

# %%
recent_grads.plot(x='Sample_size', y='Unemployment_rate', kind='scatter', title='Unemployment_rate v Sample Size')

# %%
recent_grads.plot(x='Full_time', y='Median', kind='scatter', title='Median v Full time')

# %%
recent_grads.plot(x='ShareWomen', y='Unemployment_rate', kind='scatter', title='Unemployment_rate v Sharewomen')

# %%
recent_grads.plot(x='Men', y='Median', kind='scatter', title='Median v Men')

# %%
recent_grads.plot(x='Women', y='Median', kind='scatter', title='Median v Women')

# %%
women_major = recent_grads[['Major', 'Women']]
women_major.sort_values(['Women'], ascending=False)
# Out:
#                                                  Major     Women
# 145                                         PSYCHOLOGY  307087.0
# 34                                             NURSING  187621.0
# 123                                            BIOLOGY  168947.0
# 138                               ELEMENTARY EDUCATION  157833.0
# 76              BUSINESS MANAGEMENT AND ADMINISTRATION  156118.0
# 93                                      COMMUNICATIONS  143377.0
# 137                    ENGLISH LANGUAGE AND LITERATURE  136446.0
# 77                    MARKETING AND MARKETING RESEARCH  126354.0
# 113                                  GENERAL EDUCATION  116825.0
# 40                                          ACCOUNTING  104114.0
# 57                                    GENERAL BUSINESS  102352.0
# 78                    POLITICAL SCIENCE AND GOVERNMENT   88741.0
# 124                                          SOCIOLOGY   82923.0
# ...

# %%
recent_grads.describe()
# Out:
#              Rank   Major_code          Total            Men          Women  \
# count  172.000000   172.000000     172.000000     172.000000     172.000000
# mean    87.377907  3895.953488   39370.081395   16723.406977   22646.674419
# std     49.983181  1679.240095   63483.491009   28122.433474   41057.330740
# min      1.000000  1100.000000     124.000000     119.000000       0.000000
# 25%     44.750000  2403.750000    4549.750000    2177.500000    1778.250000
# 50%     87.500000  3608.500000   15104.000000    5434.000000    8386.500000
# 75%    130.250000  5503.250000   38909.750000   14631.000000   22553.750000
# max    173.000000  6403.000000  393735.000000  173809.000000  307087.000000
#
#        ShareWomen  Sample_size      Employed      Full_time      Part_time  \
# count  172.000000   172.000000     172.00000     172.000000     172.000000
# mean     0.522223   357.941860   31355.80814   26165.767442    8877.232558
# ...

# %%
recent_grads['Sample_size'].hist(bins=50, range=(0,5000))

# %%
recent_grads['Median'].hist(bins=25, range=(20000,110000))

# %%
recent_grads['Employed'].hist(bins=25, range=(0,31000))

# %%
recent_grads['Full_time'].hist(bins=25, range=(100,26000))

# %%
recent_grads['ShareWomen'].hist(bins=10, range=(0,1))

# %%
recent_grads['Unemployment_rate'].hist(bins=10, range=(0,0.20))

# %%
recent_grads['Men'].hist(bins=10, range=(100,180000))

# %%
recent_grads['Women'].hist(bins=10, range=(0,310000))

# %%
from pandas.tools.plotting import scatter_matrix 

scatter_matrix(recent_grads[['Sample_size', 'Median']], figsize=(10,10))
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x7f9476af5828>,
# ...
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f94768e22e8>]], dtype=object)

# %%
scatter_matrix(recent_grads[['Sample_size', 'Median','Unemployment_rate']], figsize=(10,10))
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x7f947691a940>,
# ...
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f94766467b8>]], dtype=object)

# %%
pay_jobs = recent_grads[['Major','Median', 'ShareWomen']]
pay_jobs = pay_jobs.sort_values('Median', ascending=False)
pay_jobs.head(10)
# Out:
#                                         Major  Median  ShareWomen
# 0                       PETROLEUM ENGINEERING  110000    0.120564
# 1              MINING AND MINERAL ENGINEERING   75000    0.101852
# 2                   METALLURGICAL ENGINEERING   73000    0.153037
# 3   NAVAL ARCHITECTURE AND MARINE ENGINEERING   70000    0.107313
# 4                        CHEMICAL ENGINEERING   65000    0.341631
# 5                         NUCLEAR ENGINEERING   65000    0.144967
# 6                           ACTUARIAL SCIENCE   62000    0.441356
# 7                  ASTRONOMY AND ASTROPHYSICS   62000    0.535714
# 10                       COMPUTER ENGINEERING   60000    0.199413
# 13                          MATERIALS SCIENCE   60000    0.310820

# %%
pay_jobs.tail(10)
# Out:
#                            Major  Median  ShareWomen
# 164    EARLY CHILDHOOD EDUCATION   28000    0.968954
# 162  ANTHROPOLOGY AND ARCHEOLOGY   28000    0.707136
# 165      OTHER FOREIGN LANGUAGES   27500    0.690111
# 166       DRAMA AND THEATER ARTS   27000    0.666119
# 167     COMPOSITION AND RHETORIC   27000    0.629505
# 168                      ZOOLOGY   26000    0.637293
# 169       EDUCATIONAL PSYCHOLOGY   25000    0.817099
# 170          CLINICAL PSYCHOLOGY   25000    0.799859
# 171        COUNSELING PSYCHOLOGY   23400    0.798746
# 172              LIBRARY SCIENCE   22000    0.877960

# %%
pay_jobs.head(10).plot.bar(x='Major', y='ShareWomen')

# %%
pay_jobs.tail(10).plot.bar(x='Major', y='ShareWomen')

# %%
pay_jobs = recent_grads[['Major','Median', 'Unemployment_rate']]
pay_jobs = pay_jobs.sort_values('Median', ascending=False)
pay_jobs.head(10)
# Out:
#                                         Major  Median  Unemployment_rate
# 0                       PETROLEUM ENGINEERING  110000           0.018381
# 1              MINING AND MINERAL ENGINEERING   75000           0.117241
# 2                   METALLURGICAL ENGINEERING   73000           0.024096
# 3   NAVAL ARCHITECTURE AND MARINE ENGINEERING   70000           0.050125
# 4                        CHEMICAL ENGINEERING   65000           0.061098
# 5                         NUCLEAR ENGINEERING   65000           0.177226
# 6                           ACTUARIAL SCIENCE   62000           0.095652
# 7                  ASTRONOMY AND ASTROPHYSICS   62000           0.021167
# 10                       COMPUTER ENGINEERING   60000           0.065409
# 13                          MATERIALS SCIENCE   60000           0.023043

# %%
pay_jobs = recent_grads[['Major','Median', 'Unemployment_rate']]
pay_jobs = pay_jobs.sort_values('Median', ascending=False)
pay_jobs.tail(10)
# Out:
#                            Major  Median  Unemployment_rate
# 164    EARLY CHILDHOOD EDUCATION   28000           0.040105
# 162  ANTHROPOLOGY AND ARCHEOLOGY   28000           0.102792
# 165      OTHER FOREIGN LANGUAGES   27500           0.107116
# 166       DRAMA AND THEATER ARTS   27000           0.077541
# 167     COMPOSITION AND RHETORIC   27000           0.081742
# 168                      ZOOLOGY   26000           0.046320
# 169       EDUCATIONAL PSYCHOLOGY   25000           0.065112
# 170          CLINICAL PSYCHOLOGY   25000           0.149048
# 171        COUNSELING PSYCHOLOGY   23400           0.053621
# 172              LIBRARY SCIENCE   22000           0.104946

# %%
pay_jobs.head(10).plot.bar(x='Major', y='Unemployment_rate')

# %%
pay_jobs.tail(10).plot.bar(x='Major', y='Unemployment_rate')
